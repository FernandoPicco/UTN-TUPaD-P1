# %% [markdown]
# <h2>
# <font color="#032766">
# <b>
# PROGRAMACIÓN 1
# </b>
# </font>
# </h2>
#
#
# <h3>
# <font color="#032766">
# <b>
# Trabajo práctico 7: Estructuras de Datos Complejas
# </b>
# </font>
# </h3>

# %% [markdown]
# Ejercicio 1
#
# Dado el diccionario precios_frutas
#
# precios_frutas = {'Banana': 1200, 'Ananá': 2500, 'Melón': 3000, 'Uva':
# 1450}
#
# Añadir las siguientes frutas con sus respectivos precios:
#
# ● Naranja = 1200
#
# ● Manzana = 1500
#
# ● Pera = 2300

# %%
# Diccionario
precio_frutas = {'Banana': 1200, 'Ananá': 2500, 'Melón': 3000, 'Uva': 1450}

# Para agregar frutas:
precio_frutas['Naranja'] = 1200
precio_frutas['Manzana'] = 1500
precio_frutas['Pera'] = 2300

print(precio_frutas)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 5
#       2 precio_frutas = {'Banana': 1200, 'Ananá': 2500, 'Melón': 3000, 'Uva': 1450}
#       4 # Para agregar frutas:
# ----> 5 precio_frutas['Naranja': 1200]
#       6 precio_frutas['Manzana': 1500]
#       7 precio_frutas['Pera': 2300]
#
# KeyError: slice('Naranja', 1200, None)
