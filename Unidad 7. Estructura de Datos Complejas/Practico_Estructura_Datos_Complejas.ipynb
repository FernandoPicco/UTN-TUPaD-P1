# %% [markdown]
# <h2>
# <font color="#032766">
# <b>
# PROGRAMACIÓN 1
# </b>
# </font>
# </h2>
#
#
# <h3>
# <font color="#032766">
# <b>
# Trabajo práctico 7: Estructuras de Datos Complejas
# </b>
# </font>
# </h3>

# %% [markdown]
# Ejercicio 1
#
# Dado el diccionario precios_frutas
#
# precios_frutas = {'Banana': 1200, 'Ananá': 2500, 'Melón': 3000, 'Uva':
# 1450}
#
# Añadir las siguientes frutas con sus respectivos precios:
#
# ● Naranja = 1200
#
# ● Manzana = 1500
#
# ● Pera = 2300

# %%
# Diccionario
precio_frutas = {'Banana': 1200, 'Ananá': 2500, 'Melón': 3000, 'Uva': 1450}

# Para agregar frutas:
precio_frutas['Naranja'] = 1200
precio_frutas['Manzana'] = 1500
precio_frutas['Pera'] = 2300

print(precio_frutas)
# Out:
# {'Banana': 1200, 'Ananá': 2500, 'Melón': 3000, 'Uva': 1450, 'Naranja': 1200, 'Manzana': 1500, 'Pera': 2300}

# %% [markdown]
# Ejercicio 2
#
# Siguiendo con el diccionario precios_frutas que resulta luego de ejecutar el código desarrollado en el punto anterior, actualizar los precios de las siguientes frutas:
#
# ● Banana = 1330
#
# ● Manzana = 1700
#
# ● Melón = 2800

# %%
# Diccionario
precio_frutas = {'Banana': 1200, 'Ananá': 2500, 'Melón': 3000, 'Uva': 1450}

# Para actualizar los precios de las frutas:
precio_frutas['Banana'] = 1330
precio_frutas['Manzana'] = 1700
precio_frutas['Melón'] = 2800

print(precio_frutas)
# Out:
# {'Banana': 1330, 'Ananá': 2500, 'Melón': 2800, 'Uva': 1450, 'Manzana': 1700}

# %% [markdown]
# Ejercicio 3
#
# Siguiendo con el diccionario precios_frutas que resulta luego de ejecutar el código desarrollado en el punto anterior, crear una lista que contenga únicamente las frutas sin los precios.

# %%
# Diccionario
precio_frutas = {'Banana': 1330, 'Ananá': 2500, 'Melón': 2800, 'Uva': 1450, 'Manzana': 1700}

# creació de la lista precio_frutas sin precios:

frutas_sin_precios = [
    'Banana', 'Ananá', 'Melón', 'Uva', 'Manzana'
]
# otra forma de crear una lista solo con las frutas (claves):
# lista_frutas = list(precios_frutas.keys())
# print(lista_frutas)
precio_frutas
print(f"Precio de frutas: \n{precio_frutas}")
print(f"Lista de frutas: \n{frutas_sin_precios}")
# Out:
# Precio de frutas:
# {'Banana': 1330, 'Ananá': 2500, 'Melón': 2800, 'Uva': 1450, 'Manzana': 1700}
# Lista de frutas:
# ['Banana', 'Ananá', 'Melón', 'Uva', 'Manzana']

# %% [markdown]
# Ejercicio 4
#
# Escribí un programa que permita almacenar y consultar números telefónicos.
#
# • Permití al usuario cargar 5 contactos con su nombre como clave y número como valor.
#
# • Luego, pedí un nombre y mostrale el número asociado, si existe.
#
# Ejemplo:
#
# contactos = {"Juan": "123456", "Ana": "987654"}
#
# #Consultar: "Juan" -> muestra "123456"

# %%
# Crear un diccionario vacío
contactos = {}

for i in range(5): # permite al usuario almacenar 5 contactos (nombre + nro. telefónico)
    nombre = input(f"Ingrese el nombre del contacto {i+1}: ").strip().lower()
    numero = input(f"Ingrese el número telefónico de {nombre}: ").strip()
    contactos[nombre] = numero
print("Contactos almacenados correctamente: ")
print(contactos)

# Luego permitirle al usuario consultar sobre la existencia de un nombre y poder mostrarle el nro. telefónico.
consulta_nombre = input("Ingrese el nombre que desea consultar: ").strip().lower()

if consulta_nombre in contactos:
    print(f"El número telefónico de {consulta_nombre} es: {contactos[consulta_nombre]}")
else:
    print(f"No existe un contacto con el nombre '{consulta_nombre}'")
# Out:
# Contactos almacenados correctamente:
# {'fernando': '123', 'pedro': '456', 'claudio': '789', 'vale': '101112', 'andre': '12345566'}
# El número telefónico de andre es: 12345566

# %% [markdown]
# Ejercicio 5
#
# Solicita al usuario una frase e imprime:
#
# • Las palabras únicas (usando un set).
#
# • Un diccionario con la cantidad de veces que aparece cada palabra.
#
# Ejemplo:
#
# ![image.png](attachment:image.png)

# %%
# Pido frase al usuario
frase_usuario = input("Ingrese una frase: ")

# convertimos la frase ingresada por el usuario a lista de palabras
l_palabras = frase_usuario.split()

# prueba => print(l_palabras)

# utilizo set para lograr que las palabras sean únicas

unica_palabra = set(l_palabras)

# por último utilizo diccionario para contar apariciones

cant_palabras = {}
for i in l_palabras:
    if i in cant_palabras:
        cant_palabras[i] += 1
    else:
        cant_palabras[i] = 1

# Muestro los resultados
print("Palabras_Únicas: ", unica_palabra)
print("Recuento: ", cant_palabras)
# Out:
# Palabras_Únicas:  {'Fernando', 'Tigre'}
# Recuento:  {'Fernando': 3, 'Tigre': 1}

# %% [markdown]
# Ejercicio 6
#
# Permití ingresar los nombres de 3 alumnos, y para cada uno una tupla de 3 notas.
#
# Luego, mostrá el promedio de cada alumno.
#
# Ejemplo:
#
# ![image.png](attachment:image.png)

# %%
# creamos el diccionario donde se guardan los nombres de los alumnos y las notas correspondientes:
alumnos = {}

# ciclo for para pedir nombres y notas de los 3 alumnos

for i in range(3):
    nombre = input(f"Ingrese el nombre del alumno {i+1}: ").strip()
    #print(nombre)

    print(f"Ingrese las 3 notas de {nombre}: ")

    # Validación para que no se pueda escribir "nada" y que el usuario está obligado a ingresa un nro.
    while True:
        primera_nota = input("Primera nota: ").strip()
        if primera_nota.isdigit():
            primera_nota = float(primera_nota)
            break
        else:
            print("Ingrese una nota válida (el ingreso no puede quedar vacío).")
    
    while True:
        segunda_nota = input("Segunda nota: ").strip()
        if segunda_nota.isdigit():
            segunda_nota = float(segunda_nota)
            break
        else:
            print("Ingrese una nota válida (el ingreso no puede quedar vacío).")
    
    while True:
        tercera_nota = input("Tercera nota: ").strip()
        if tercera_nota.isdigit():
            tercera_nota = float(tercera_nota)
            break
        else:
            print("Ingrese una nota válida (el ingreso no puede quedar vacío).")


    # guardo las notas en una tupla (diccionario)
    alumnos[nombre] = (primera_nota, segunda_nota, tercera_nota)

# Procedimiento para obtener y mostrar el promedio
print("Promedio de alumnos: ")
for nombre, notas in alumnos.items():
    promedio = sum(notas) / len(notas)

    print(f"{nombre}: {promedio:.2f}") # el promedio se muestra con 2 decimales
# Out:
# Ingrese las 3 notas de Fer:
# Ingrese las 3 notas de Pablo:
# Ingrese las 3 notas de Vale:
# Ingrese una nota válida (el ingreso no puede quedar vacío).
# Ingrese una nota válida (el ingreso no puede quedar vacío).
# Promedio de alumnos:
# Fer: 5.00
# Pablo: 8.00
# Vale: 9.00

# %% [markdown]
# Ejercicio 7
#
# Dado dos sets de números, representando dos listas de estudiantes que aprobaron Parcial 1 y Parcial 2:
#
# • Mostrá los que aprobaron ambos parciales.
#
# • Mostrá los que aprobaron solo uno de los dos.
#
# • Mostrá la lista total de estudiantes que aprobaron al menos un parcial (sin repetir).

# %%
# sets de números
parcial_1_aprobados = {1, 2, 3, 5}
parcial_2_aprobados = {3, 4, 5, 6}

# aprobados en ambos parciales
aprobados_1_2 = parcial_1_aprobados & parcial_2_aprobados

# aprobados sólo en uno de los 2 parciales

aprobados_1_o_2 = parcial_2_aprobados ^ parcial_1_aprobados

# aprobados en al menos un parial (sin repetir)

aprobados_al_menos_uno = parcial_1_aprobados | parcial_2_aprobados

# muestro los resultados
print("Resultados: \n" )
print("Aprobaron ambos parciales : ", sorted(aprobados_1_2))
print("Aprobaron uno de los dos parciales: ", sorted(aprobados_1_o_2))
print("Aprobaron al menos un parcial: ", sorted(aprobados_al_menos_uno))
# Out:
# Resultados:
#
# Aprobaron ambos parciales :  [3, 5]
# Aprobaron uno de los dos parciales:  [1, 2, 4, 6]
# Aprobaron al menos un parcial:  [1, 2, 3, 4, 5, 6]

# %% [markdown]
# Ejercicio 8
#
# Armá un diccionario donde las claves sean nombres de productos y los valores su stock.
#
# Permití al usuario:
#
# • Consultar el stock de un producto ingresado.
#
# • Agregar unidades al stock si el producto ya existe.
#
# • Agregar un nuevo producto si no existe.

# %%
# Diccionario de productos y su respectivo stock. Claves (nombres) y Valores (stock)

stock = {
    "filtro de aire": 150,
    "filtro de combustible": 120,
    "bidón de aceite x 4 Lts.": 75,
    "filtro de polen": 111
}

while True:
    print("Opciones de Menú")
    print("1. Consultar stock de un producto")
    print("2. Agregar unidades de stock a un producto existente")
    print("3. Agregar un producto nuevo")
    print("4. Salir.")

    opcion = input("Elige una de las opciones: ").strip()

    if opcion == "1":
        producto = input("Ingrese el nombre del producto: ").strip().lower()

        if producto in stock:
            print(f"Stock de {producto}: {stock[producto]} unidades")
        else: 
            print(f"El producto seleccionado '{producto}' no existe en el inventario")
    
    elif opcion == "2":
        producto = input("producto al que desea agregar stock: ").strip().lower()
        if producto in stock:
            while True:
                cantidad = input("Cantidad a agregar: ").strip()
                if cantidad.isdigit():
                    cantidad = int(cantidad)
                    stock[producto] += cantidad
                    print(f"Se agregaron {cantidad} unidades de stock a {producto}. Nuevo Stock: {stock[producto]}")
                    break
                else: 
                    print("Ingrese un número válido.")
        else:
            print("El producto no existe. Ingrese la opción 3 para adicionarlo.")
        
    elif opcion == "3":
        producto_nuevo = input("Ingrese el nombre del nuevo producto: ").strip().lower()
        if producto_nuevo in stock:
            print("El producto ingresado existe.")
        else:
            while True:
                cantidad = input("Ingrese la cantidad inicial: ").strip()
                if cantidad.isdigit():
                    cantidad = int(cantidad)
                    stock[producto_nuevo] = cantidad
                    print(f"El producto '{producto_nuevo}' agregado con {cantidad} unidades.")
                    break
                else:
                    print("Ingrese un número válido.")
    
    elif opcion == "4":
        print("Hasta pronto!")
        break    
    else: 
        print("Opción inválida.")

# %% [markdown]
# Ejercicio 9
#
# Creá una agenda donde las claves sean tuplas de (día, hora) y los valores sean eventos.
#
# Ejemplo:
#
# ![image.png](attachment:image.png)
#
# Permití consultar qué actividad hay en cierto día y hora.

# %%
# Creación del diccionario (agenda)

agenda = {
    ("lunes", "09:00"): "Runión de Equipo",
    ("martes", "11:15"):"Apertura de auditoría",
    ("Miércoles, 15:30"):"Visita de Proveedor"
}

# Generación de solicitud de tipo de actividad según día y horario
dia = input("Ingrese el día (lun a vie): ").strip().lower()
hora = input("Ingrese una hora (HH:MM): ").strip()

# creación de la tupla "clave"
clave = (dia, hora)

# proceso para buscar clave en agenda
if clave in agenda:
    print(f"Actividad: '{agenda[clave]}'")

else:
    print("No hay actividades agendadas en ese día y hora.")
# Out:
# No hay actividades agendadas en ese día y hora.

# %% [markdown]
# Ejercicio 10
#
# Dado un diccionario que mapea nombres de países con sus capitales, construí un nuevo diccionario donde:
#
# • Las capitales sean las claves.
#
# • Los países sean los valores.
#
# Ejemplo:
#
# ![image.png](attachment:image.png)

# %%
# Creación de diccionario que mapea nombres de países con sus capitales

original = {"Argentina": "Buenos Aires", "Chile": "Santiago", "Brasil": "Brasilia", "Paraguay":"Asunción"}

# proceso para la construcción de diccionario invertido----> clave = capital y valor = país

invertido = {}

for x, i in original.items():
    invertido[i] = x

# mostrar el diccionario invertido

print("Diccionario original: ", original)
print("Diccionario invertido: ", invertido)
# Out:
# Diccionario original:  {'Argentina': 'Buenos Aires', 'Chile': 'Santiago', 'Brasil': 'Brasilia', 'Paraguay': 'Asunción'}
# Diccionario invertido:  {'Buenos Aires': 'Argentina', 'Santiago': 'Chile', 'Brasilia': 'Brasil', 'Asunción': 'Paraguay'}
